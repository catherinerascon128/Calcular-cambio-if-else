# %% [markdown]
# <a href="https://colab.research.google.com/github/catherinerascon128/Calcular-cambio-if-else/blob/main/El_alumno_Act_12_cambio_catherine_rascon_0072.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Catherine rascon NL = 26 Fechas 26/mar/26 ⛲
# ### calculando el cambio usandi if, else
# ### mirar diagrama ♈
# <img src="https://raw.githubusercontent.com/catherinerascon128/Calcular-cambio-if-else/refs/heads/main/cambio.png" width="400" height="400" alt="Imagen de ejemplo" />
#
# ## las variables ✅
# 1. CP -- coxto del producto
# 2. CD -- cantidad de dinero
# 3. Cambio
#
# ## Formulas ◀
# $cambio = CD - CP$
#
# ## Diagrama de flujo LucidChat ⚡
# <img src="https://raw.githubusercontent.com/catherinerascon128/Calcular-cambio-if-else/refs/heads/main/DF%20if%20else%20cambio%202.png" width="350" height="500" alt="Imagen de ejemplo" />

# %%
# para cuando es verdadero (si)
# calcular el cambio usando if else
# datos de entrada CP, CD
# mostrar cambio si es falso
#si es verdadero mostrar no alcanza
CP = float(input("ingrese el costo del producto: "))
CD = float(input("ingrese la cantidad de dinero: "))
if CP > CD:
    print("no alcanza")
else:
    cambio = CD - CP
    print("el cambio es:", cambio)
    print("programa realizado por catherine rascon NL = 26")
# Out:
# ingrese el costo del producto: 78
# ingrese la cantidad de dinero: 50
# no alcanza

# %%
# para cuando es falso (no)
# calcular el cambio usando if else
# datos de entrada CP, CD
# mostrar cambio si es falso
#si es verdadero mostrar no alcanza
CP = float(input("ingrese el costo del producto: "))
CD = float(input("ingrese la cantidad de dinero: "))
if CP > CD:
    print("no alcanza")
else:
    cambio = CD - CP
    print("el cambio es:", cambio)
    print("programa realizado por catherine rascon NL = 26")
# Out:
# ingrese el costo del producto: 56
# ingrese la cantidad de dinero: 89
# el cambio es: 33.0
# programa realizado por catherine rascon NL = 26

# %% [markdown]
# ## relacion entre codigo y diagrama de flujo ⚛
# <img src="https://raw.githubusercontent.com/catherinerascon128/Calcular-cambio-if-else/refs/heads/main/TL%20draw%20DF%20y%20cofigo%20cambio.png" width="" height="400" alt="Imagen de ejemplo" />
